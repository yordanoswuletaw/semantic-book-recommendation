# %%
import numpy as np
import pandas as pd 
from tqdm import tqdm
from transformers import pipeline

# %%
books = pd.read_csv('../data/books_cleaned_with_categories.csv')
classifier = pipeline('text-classification', 
    model='j-hartmann/emotion-english-distilroberta-base', 
    top_k=None)
classifier('I love this :(')
# Out:
# Device set to use cpu
# [[{'label': 'joy', 'score': 0.8908524513244629},
#   {'label': 'neutral', 'score': 0.05040666088461876},
#   {'label': 'sadness', 'score': 0.03542739152908325},
#   {'label': 'surprise', 'score': 0.009478951804339886},
#   {'label': 'disgust', 'score': 0.007098732981830835},
#   {'label': 'anger', 'score': 0.005757557228207588},
#   {'label': 'fear', 'score': 0.0009783386485651135}]]

# %%
def calculate_max_emotion_scores(predictions, emotion_labels):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        for each in prediction:
            label, score = each['label'], each['score']
            per_emotion_scores[label].append(score)
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
isbn = []
emotion_labels = ['anger', 'fear', 'joy', 'disgust', 'sadness', 'surprise', 'neutral']
emotion_scores = {label: [] for label in emotion_labels}
for i in tqdm(range(books.shape[0])):
    isbn.append(books.loc[i, 'isbn13'])
    sentences = books.loc[i, 'description'].split('.')
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions, emotion_labels)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [24:03<00:00,  3.60it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df['isbn13'] = isbn
emotions_df.head()
# Out:
#       anger      fear       joy   disgust   sadness  surprise   neutral  \
# 0  0.064133  0.928168  0.932798  0.273592  0.967158  0.729602  0.646216
# 1  0.612619  0.942528  0.704422  0.348285  0.111690  0.252546  0.887940
# 2  0.064133  0.972321  0.767238  0.104007  0.111690  0.078765  0.549478
# 3  0.351484  0.360706  0.251881  0.150722  0.111690  0.078765  0.732685
# 4  0.081412  0.095043  0.040564  0.184495  0.475881  0.078765  0.884390
#
#           isbn13
# 0  9780002005883
# 1  9780002261982
# 2  9780006178736
# 3  9780006280897
# 4  9780006280934

# %%
books = pd.merge(books, emotions_df, on='isbn13')
books.head()
# Out:
#           isbn13      isbn10                title  \
# 0  9780002005883  0002005883               Gilead
# 1  9780002261982  0002261987         Spider's Web
# 2  9780006178736  0006178731       Rage of angels
# 3  9780006280897  0006280897       The Four Loves
# 4  9780006280934  0006280935  The Problem of Pain
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2                   Sidney Sheldon                        Fiction
# 3              Clive Staples Lewis                 Christian life
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=FKo2T...
# 3  http://books.google.com/books/content?id=XhQ5X...
# 4  http://books.google.com/books/content?id=Kk-uV...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2  A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3  Lewis' work on the nature of love divides love...          2002.0
# 4  "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
#
#    average_rating  num_pages  ...  \
# 0            3.85      247.0  ...
# 1            3.83      241.0  ...
# 2            3.93      512.0  ...
# 3            4.15      170.0  ...
# 4            4.09      176.0  ...
#
#                                   tagged_description sample_categories  \
# 0  9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1  9780002261982 A new 'Christie for Christmas' -...               NaN
# 2  9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3  9780006280897 Lewis' work on the nature of lov...               NaN
# 4  9780006280934 "In The Problem of Pain, C.S. Le...               NaN
#
#   simple_categories     anger      fear       joy   disgust   sadness  \
# 0           Fiction  0.064133  0.928168  0.932798  0.273592  0.967158
# 1           Fiction  0.612619  0.942528  0.704422  0.348285  0.111690
# 2           Fiction  0.064133  0.972321  0.767238  0.104007  0.111690
# 3        Nonfiction  0.351484  0.360706  0.251881  0.150722  0.111690
# 4        Nonfiction  0.081412  0.095043  0.040564  0.184495  0.475881
#
#    surprise   neutral
# 0  0.729602  0.646216
# 1  0.252546  0.887940
# 2  0.078765  0.549478
# 3  0.078765  0.732685
# 4  0.078765  0.884390
#
# [5 rows x 22 columns]

# %%
books.to_csv('../data/books_cleaned_with_emotions.csv', index=False)
